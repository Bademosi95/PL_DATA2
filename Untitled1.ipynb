# %%
import weekly_update
weekly_update.main()
# Out:
# 2026-01-03 14:39:38,663 [INFO]
# ...
# 2026-01-03 14:39:38,670 [INFO] WEEKLY MODEL UPDATE PIPELINE
# 2026-01-03 14:39:38,677 [INFO] Started: 2026-01-03T14:39:38.663481
# 2026-01-03 14:39:38,684 [INFO] ======================================================================
#
# 2026-01-03 14:39:38,688 [INFO] ======================================================================
# 2026-01-03 14:39:38,692 [INFO] LOADING DATA
# 2026-01-03 14:39:38,700 [INFO] ======================================================================
# [weekly_update] Running enhanced_v3_ewma_draw_calib_2025-12-20
# 2026-01-03 14:39:38,965 [INFO] Loaded 190 matches from PL_Scores_25.csv
# 2026-01-03 14:39:38,967 [INFO] Loaded 20 team records from premier_league_stats.csv
# 2026-01-03 14:39:39,028 [INFO]
# Parsing scores...
# 2026-01-03 14:39:39,140 [INFO]
# ...
# 2026-01-03 14:39:39,142 [INFO] DATA QUALITY CHECKS
# 2026-01-03 14:39:39,143 [INFO] ======================================================================
# ...
