# %%
import weekly_update
weekly_update.main()
# Out:
# 2025-12-29 18:05:33,694 [INFO]
# ...
# 2025-12-29 18:05:33,696 [INFO] WEEKLY MODEL UPDATE PIPELINE
# 2025-12-29 18:05:33,697 [INFO] Started: 2025-12-29T18:05:33.694888
# 2025-12-29 18:05:33,699 [INFO] ======================================================================
#
# 2025-12-29 18:05:33,701 [INFO] ======================================================================
# 2025-12-29 18:05:33,702 [INFO] LOADING DATA
# 2025-12-29 18:05:33,704 [INFO] ======================================================================
# 2025-12-29 18:05:33,891 [INFO] Loaded 180 matches from PL_Scores_25.csv
# 2025-12-29 18:05:33,893 [INFO] Loaded 20 team records from premier_league_stats.csv
# [weekly_update] Running enhanced_v3_ewma_draw_calib_2025-12-20
# 2025-12-29 18:05:33,925 [INFO]
# Parsing scores...
# 2025-12-29 18:05:33,984 [INFO]
# ...
# 2025-12-29 18:05:33,985 [INFO] DATA QUALITY CHECKS
# 2025-12-29 18:05:33,986 [INFO] ======================================================================
# ...
