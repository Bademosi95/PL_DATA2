# %%
import importlib, weekly_update
importlib.reload(weekly_update)
weekly_update.main()
# Out:
# 2026-01-17 10:45:55,759 [INFO]
# ...
# 2026-01-17 10:45:55,760 [INFO] WEEKLY MODEL UPDATE PIPELINE
# 2026-01-17 10:45:55,762 [INFO] Started: 2026-01-17T10:45:55.759824
# 2026-01-17 10:45:55,764 [INFO] ======================================================================
#
# 2026-01-17 10:45:55,766 [INFO] ======================================================================
# 2026-01-17 10:45:55,767 [INFO] LOADING DATA
# 2026-01-17 10:45:55,768 [INFO] ======================================================================
# 2026-01-17 10:45:55,785 [INFO] Loaded 210 matches from PL_Scores_25.csv
# 2026-01-17 10:45:55,787 [INFO] Loaded 20 team records from premier_league_stats.csv
# 2026-01-17 10:45:55,793 [INFO]
# Parsing scores...
# 2026-01-17 10:45:55,814 [INFO]
# ...
# 2026-01-17 10:45:55,816 [INFO] DATA QUALITY CHECKS
# 2026-01-17 10:45:55,817 [INFO] ======================================================================
# 2026-01-17 10:45:55,819 [INFO]
# ...
